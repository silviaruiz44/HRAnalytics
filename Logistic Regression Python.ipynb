# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from patsy import dmatrices
import numpy as np

# %%
Xtrain=pd.read_csv('Train.csv')
Xtest=pd.read_csv('Test.csv')
Xtrain_over=pd.read_csv('Train_over.csv')
Xtest_over=pd.read_csv('Test_over.csv')
Xtrain_under=pd.read_csv('Train_under.csv')
Xtest_under=pd.read_csv('Test_under.csv')

data=Xtrain
y=data['Attrition2']
data=data.drop(['Attrition1', 'Attrition2'], axis=1)

# %%
y_train=Xtrain['Attrition2']
y_test=Xtest['Attrition2']
y_train_over=Xtrain_over['Attrition2']
y_test_over=Xtest_over['Attrition2']
y_train_under=Xtrain_under['Attrition2']
y_train_under=Xtest_under['Attrition2']

Xtrain=Xtrain.drop(['Attrition1', 'Attrition2'], axis=1)
Xtest=Xtest.drop(['Attrition1', 'Attrition2'], axis=1)
Xtrain_over=Xtrain_over.drop(['Attrition1', 'Attrition2'], axis=1)
Xtest_over=Xtest_over.drop(['Attrition1', 'Attrition2'], axis=1)
Xtrain_under=Xtrain_under.drop(['Attrition1', 'Attrition2'], axis=1)
Xtest_under=Xtest_under.drop(['Attrition1', 'Attrition2'], axis=1)

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
fit=logreg.fit(Xtrain, y_train)

# %%
train_cols = data.columns[1:]
print(len(Xtrain))
print(len(y_train))
logit = sm.Logit(y_train, Xtrain)

result1 = logit.fit()
result1.summary()
#result2 = logit2.fit()
#result3 = logit3.fit()
# Out:
# 3289
# 3289
# Optimization terminated successfully.
#          Current function value: 0.349481
#          Iterations 7
# /anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1092: RuntimeWarning: invalid value encountered in sqrt
#   bse_ = np.sqrt(np.diag(self.cov_params()))
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:             Attrition2   No. Observations:                 3289
# ...

# %%
logit2 = sm.Logit(y_train_over, Xtrain_over)
result2 = logit2.fit()
result2.summary()
np.exp(result2.params)
#logit3 = sm.Logit(y_train_under, Xtrain_under)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.535993
#          Iterations 11
# /anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:1092: RuntimeWarning: invalid value encountered in sqrt
#   bse_ = np.sqrt(np.diag(self.cov_params()))
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# Department_Sales                       1.034938
# Department_ResearchDevelopment         1.038488
# Department_HumanResources              2.737940
# EducationField_LifeSciences            1.381976
# ...

# %%
logit3 = sm.Logit(y_train_under, Xtrain_under)
result3 = logit3.fit()
result3.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-cc20612dff98> in <module>()
# ----> 1 logit3 = sm.Logit(y_train_under, Xtrain_under)
#       2 result3 = logit3.fit()
#       3 result3.summary()
#
# /anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py in __init__(self, endog, exog, **kwargs)
#     416
#     417     def __init__(self, endog, exog, **kwargs):
# --> 418         super(BinaryModel, self).__init__(endog, exog, **kwargs)
#     419         if (not issubclass(self.__class__, MultinomialModel) and
#     420                 not np.all((self.endog >= 0) & (self.endog <= 1))):
#
# /anaconda3/lib/python3.6/site-packages/statsmodels/discrete/discrete_model.py in __init__(self, endog, exog, **kwargs)
#     169     """
#     170     def __init__(self, endog, exog, **kwargs):
# ...
